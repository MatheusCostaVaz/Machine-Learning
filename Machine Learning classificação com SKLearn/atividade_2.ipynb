# %%
import pandas as pd

# %%
uri = "https://raw.githubusercontent.com/MatheusCostaVaz/Machine-Learning/main/Machine%20Learning%20classifica%C3%A7%C3%A3o%20com%20SKLearn/Planilha%20sem%20t%C3%ADtulo%20-%20Bens%20e%20Direitos.csv"
dados = pd.read_csv(uri)
dados.head()
# Out:
#    Ano Calendário Ações (inclusive as provenientes de linha telefônica)  \
# 0            2020                                        616501,6239
# 1            2019                                        610547,7567
# 2            2018                                        454157,4772
# 3            2017                                        426490,0447
# 4            2016                                        383912,1782
#
#       Aeronave  Apartamento Aplicação de renda fixa (CDB, RDB e outros)  \
# 0  3874,382955  1605524,488                                  850794,786
# 1  3460,319785   1503879,39                                 756101,9056
# 2  3126,573347  1386696,893                                 688038,5242
# 3  2905,160337  1295027,635                                  629640,395
# 4  2828,510999   1169218,62                                 593173,1398
#
#   Bem relacionado com o exercício da atividade autônoma Benfeitorias  \
# ...
